# %%
# 作業1

1. 你選的這組資料為何重要

了解歐洲各區風力電廠發電效率, 以推測風場分布

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

European Commission's STETIS program

3. 蒐集而來的資料型態為何

結構化資料

4. 這組資料想解決的問題如何評估

依各電廠產電平均值, 推估個月相對風量

依各電廠相對風量推估風場分布

# %%
import pandas as pd
df = pd.read_csv('../data/TS.CF.N2.30yr.csv')
df
# Out:
#            PL41     ES21     PL32     UKK1     PL34     ES24     CZ06  \
# 0       0.02459  0.21347  0.07598  0.54705  0.16948  0.74278  0.19489
# 1       0.01484  0.20183  0.08367  0.44395  0.16234  0.67600  0.20313
# 2       0.00972  0.19800  0.09651  0.29984  0.15206  0.56476  0.18398
# 3       0.00983  0.21373  0.08960  0.18699  0.14123  0.51820  0.13743
# 4       0.00855  0.25338  0.08422  0.06668  0.12608  0.48668  0.09395
# 5       0.01072  0.32322  0.09259  0.04675  0.11158  0.47599  0.06655
# 6       0.01695  0.39983  0.09248  0.05119  0.09848  0.51257  0.04809
# 7       0.02895  0.46698  0.11102  0.07198  0.08874  0.55768  0.03817
# 8       0.03292  0.54667  0.12400  0.17523  0.05779  0.65215  0.04404
# 9       0.02148  0.56828  0.12769  0.28923  0.03377  0.61494  0.01482
# 10      0.01704  0.57583  0.11309  0.44595  0.03160  0.59302  0.00210
# 11      0.01899  0.70770  0.09435  0.73461  0.03799  0.61404  0.00000
# ...

# %%
# 作業2

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

尖峰時刻, 乘客上下車點分布, 以調整客單選擇

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

內部收集

Time vs. 接單量, 乘車/目的地, 金額

3. 蒐集而來的資料型態為何

結構化資料

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

確認尖峰時間(time vs. 接單量)

在尖峰時間區間, 確認乘車/目的地數量

依乘車/目的地為成本, 換算金額/成本調整客單選擇

# %%
# 統計指標實作範例
## 常見於迴歸問題的評估指標
* Mean Absolute Error (MAE)
* Mean Squared Error (MSE)

## 常見於分類問題的指標
* Binary Cross Entropy (CE)

##### 後面的課程還會有更詳細的說明

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
def mean_square_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MSE
    """
    mse = sum(((y - yp) ** 2)) ** .5 / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
